# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import cmocean as cm
import xarray as xr
import numpy as np
import IPython.display
import cosima_cookbook as cc
import pandas as pd

# %%
session = cc.database.create_session()

# %%
expList = cc.querying.get_experiments(session)

# %%
expList.loc[expList["experiment"].str.contains("01deg")]
# Out:
#                                             experiment  ncfiles
# 30                          01deg_jra55v13_ryf9091_5Kv      102
# 31                    01deg_jra55v13_ryf9091_OFAM3visc       50
# 32                          01deg_jra55v140_iaf_cycle3     4156
# 33                           01deg_jra55v140_iaf_KvJ09    18432
# 34                  01deg_jra55v13_ryf9091_k_smag_iso3      128
# 35                       01deg_jra55v140_iaf_cycle3_HF     9280
# 37                    01deg_jra55v13_ryf9091_qian_wtlp      400
# 85         01deg_jra55v13_ryf9091_rerun_for_easterlies      753
# 87                                  01deg_jra55v13_iaf     2694
# 90                   01deg_jra55_SAMextr_1011_from9091      640
# 91                          01deg_jra55v140_iaf_cycle2    25198
# 92                   01deg_jra55_SAMextr_9899_from9091      640
# 93                   01deg_jra55_SAMextr_9192_from9091      640
# 94                          01deg_jra55v140_iaf_cycle4   131990
# 105           01deg_jra55v13_ryf9091_easterlies_down10     1250
# 106                        01deg_jra55_iaf_cycle3_melt     1079
# 107       01deg_jra55v13_ryf9091_easterlies_up10_noDSW      789
# 108               01deg_jra55v13_ryf9091_weddell_down2     1061
# 109  01deg_jra55v13_ryf9091_easterlies_up10_meridional      819
# 112                  01deg_jra55_SAMextr_0203_from9091      640
# 114             01deg_jra55v13_ryf9091_easterlies_up10     1250
# 115       01deg_jra55v13_ryf9091_easterlies_up10_zonal      830
# 116                                01deg_jra55v140_iaf    26168
# 130                             01deg_jra55v13_ryf9091    13399
# 131                         01deg_jra55v13_iaf_4hourly      152
# 132                 01deg_jra55v13_ryf9091_weddell_up1     1129
# 133               01deg_jra55v13_ryf9091_weddell_down1     1130
# 134                   01deg_jra55v13_ryf9091_qian_ctrl     1440
# 151                         01deg_jra55v140_iaf_cycle3    25526
# 156     01deg_jra55v140_iaf_cycle4_jra55v150_extension    13422
# 158                         01deg_jra55v150_iaf_cycle1    24282
# 160                     01deg_jra55v150_iaf_cycle1_old    10540
# 162       01deg_jra55v140_iaf_cycle3_antarctic_tracers     6335
# 174           01deg_jra55v13_ryf9091_easterlies_down10      540
# 175                             01deg_jra55v13_ryf9091      480
# 176       01deg_jra55v13_ryf9091_easterlies_up10_zonal      378
# 177             01deg_jra55v13_ryf9091_easterlies_up10      540
# 178               01deg_jra55v13_ryf9091_weddell_down2      590
# 179  01deg_jra55v13_ryf9091_easterlies_up10_meridional      378
# 180                 01deg_jra55v13_ryf9091_weddell_up1      710
# 182                   01deg_jra55v13_ryf9091_qian_wthp     2400
# 183                  01deg_jra55v13_ryf9091_qian_wthmp     2000
# 184         01deg_jra55v140_iaf_cycle4_rerun_from_1983      172
# 185         01deg_jra55v140_iaf_cycle4_rerun_from_1986       86
# 188         01deg_jra55v140_iaf_cycle4_rerun_from_1980     2582
# 190              01deg_jra55v13_ryf9091_21mbath_CM2atm      993
# 191                     01deg_jra55v13_ryf9091_21mbath     1378
# 192                01deg_jra55v13_ryf9091_21mbath_5mdz     1544
# 202        01deg_jra55v13_ryf9091_DSW_BasalGade_YesIcb     1454
# 203       01deg_jra55v13_ryf9091_DSW_BasalNoGade_NoIcb     1649
# 204         01deg_jra55v13_ryf9091_DSW_BasalGade_NoIcb     1060
# 205               01deg_jra55v13_ryf9091_21mbath_5mtop     1207
# 206            01deg_jra55v13_ryf9091_21mbath_halfmtop     1344
# 207                      01deg_jra55v13_ryf9091_ssp585     1259
# 208                      01deg_jra55v13_ryf9091_ssp245     1259
# 209                   01deg_jra55v13_ryf9091_ssp245_mw     1259
# 210  01deg_jra55v13_ryf9091_DSW_BasalNoGade_NoIcb_b...       78
# 211    01deg_jra55v13_ryf9091_DSW_BasalGade_YesIcb_mwp       77
# 212             01deg_jra55v13_ryf9091_DSW_control_mwp       91

# %%
experiment = "01deg_jra55v140_iaf_cycle3"

# %%
fileList = cc.querying.get_ncfiles(session, experiment)

# %%
varList = cc.querying.get_variables(session, experiment=experiment, frequency="1 monthly")

# %%
varList["frequency"].unique()
# Out:
# array([None, '1 daily', '1 monthly', 'static'], dtype=object)

# %%
varList.loc[varList["long_name"].str.lower().str.contains("density")]
# Out:
#                 name                                         long_name  \
# 71               mld  mixed layer depth determined by density criteria
# 72           mld_max  mixed layer depth determined by density criteria
# 74           neutral                                   neutral density
# 75  neutralrho_edges                             neutral density edges
# 85         pot_rho_0            potential density referenced to 0 dbar
# 86         pot_rho_2         potential density referenced to 2000 dbar
# 88            potrho                                 potential density
# 89      potrho_edges                           potential density edges
#
#      units  frequency                                             ncfile  \
# 71       m  1 monthly  output731/ocean/ocean-2d-mld-1-monthly-mean-ym...
# 72       m  1 monthly  output731/ocean/ocean-2d-mld-1-monthly-max-ym_...
# 74  kg/m^3  1 monthly  output731/ocean/ocean-3d-ty_trans_nrho_submeso...
# 75  kg/m^3  1 monthly  output731/ocean/ocean-3d-ty_trans_nrho_submeso...
# 85  kg/m^3  1 monthly  output731/ocean/ocean-3d-pot_rho_0-1-monthly-m...
# 86  kg/m^3  1 monthly  output731/ocean/ocean-3d-pot_rho_2-1-monthly-m...
# 88  kg/m^3  1 monthly  output731/ocean/ocean-3d-tx_trans_rho-1-monthl...
# 89  kg/m^3  1 monthly  output731/ocean/ocean-3d-tx_trans_rho-1-monthl...
#
#    cell_methods  # ncfiles           time_start             time_end
# 71   time: mean        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 72    time: max        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 74         None        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 75         None        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 85   time: mean        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 86   time: mean        244  1958-01-01 00:00:00  2019-01-01 00:00:00
# 88         None        282  1958-01-01 00:00:00  2019-01-01 00:00:00
# 89         None        282  1958-01-01 00:00:00  2019-01-01 00:00:00

# %%
v = cc.querying.getvar(experiment, "v", session, start_time="1990-01-01", end_time="2019-01-01")

v = v.sel(yu_ocean = slice(-90, -60))

# %%
u = cc.querying.getvar(experiment, "u", session, start_time="1990-01-01", end_time="2019-01-01")

u = u.sel(yu_ocean = slice(-90, -60))

# %%
pot_rho_0 = cc.querying.getvar(experiment, "pot_rho_0", session, start_time="1990-01-01", end_time="2019-01-01")



pot_rho_0 = pot_rho_0.sel(yt_ocean = slice(-90, -60))

# %%
pot_rho_0
# Out:
# <xarray.DataArray 'pot_rho_0' (time: 351, st_ocean: 75, yt_ocean: 490,
#                                xt_ocean: 3600)>
# dask.array<getitem, shape=(351, 75, 490, 3600), dtype=float32, chunksize=(1, 19, 135, 180), chunktype=numpy.ndarray>
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean  (yt_ocean) float64 -81.11 -81.07 -81.02 ... -60.15 -60.1 -60.05
#   * st_ocean  (st_ocean) float64 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) datetime64[ns] 1989-10-16T12:00:00 ... 2018-12-16T12:00:00
# Attributes:
#     long_name:      potential density referenced to 0 dbar
#     units:          kg/m^3
#     valid_range:    [-1.e+01  1.e+05]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_potential_density
#     ncfiles:        ['/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_...
#     contact:        Andrew Kiss
#     email:          andrew.kiss@anu.edu.au
#     created:        2020-11-11
#     description:    0.1 degree ACCESS-OM2 global model configuration under in...
#     notes:          Run configuration and history: https://github.com/COSIMA/...

# %%
experiment = "01deg_jra55v13_ryf9091_qian_wthmp"

# %%
varList = cc.querying.get_variables(session, experiment=experiment, frequency="1 monthly")

# %%
varList["frequency"].unique()
# Out:
# array([None, '1 monthly', 'static'], dtype=object)

# %%
varList[varList["long_name"].str.lower().str.contains("temperature")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 varList[varList["long_name"].str.lower().str.contains("temperature")]
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/pandas/core/frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.10/lib/python3.10/site-packages/pandas/core/common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
#     131         # Don't raise on e.g. ["A", "B", np.nan], see
#     132         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 133         raise ValueError(na_msg)
#     134     return False
#     135 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
u
# Out:
# <xarray.DataArray 'u' (time: 351, st_ocean: 75, yu_ocean: 490, xu_ocean: 3600)>
# dask.array<getitem, shape=(351, 75, 490, 3600), dtype=float32, chunksize=(1, 19, 135, 180), chunktype=numpy.ndarray>
# Coordinates:
#   * xu_ocean  (xu_ocean) float64 -279.9 -279.8 -279.7 -279.6 ... 79.8 79.9 80.0
#   * yu_ocean  (yu_ocean) float64 -81.09 -81.05 -81.0 ... -60.12 -60.07 -60.02
#   * st_ocean  (st_ocean) float64 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) datetime64[ns] 1989-10-16T12:00:00 ... 2018-12-16T12:00:00
# Attributes:
#     long_name:      i-current
#     units:          m/sec
#     valid_range:    [-10.  10.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_x_velocity
#     ncfiles:        ['/g/data/cj50/access-om2/raw-output/access-om2-01/01deg_...
#     contact:        Andrew Kiss
#     email:          andrew.kiss@anu.edu.au
#     created:        2020-11-11
#     description:    0.1 degree ACCESS-OM2 global model configuration under in...
#     notes:          Run configuration and history: https://github.com/COSIMA/...

# %% [markdown]
# Watermass transformation rates are defined as:
#
# \begin{eqnarray}
#     \Omega &=& \frac{\partial}{\partial \sigma} \int \int \int \frac{D \sigma'}{D t} dV, \\
#     \Omega(\sigma, t)_{i,j} &=& A_c \frac{1}{\Delta \sigma} \sum^{N_z} \bigg (  \frac{D \sigma}{D t}  h_c \Delta z_f \delta(\sigma - \sigma') \bigg ),
# \end{eqnarray}
#
# $$ \frac{D \sigma}{Dt} = \frac{\partial \sigma}{\partial \theta} \dot{\theta} + \frac{\partial \sigma}{\partial S}\dot{S} $$
#
# $$\frac{D \theta}{Dt} = G^\theta_{hdiff} + G^\theta_{vdiff} + G^\theta_{surf} + G^\theta_{SW}$$
#
# $$\frac{D S}{Dt} = G^S_{hdiff} + G^S_{vdiff} + G^S_{surf}$$
